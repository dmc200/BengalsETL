# %%
import boto3
import pandas as pd
import psycopg2
import sqlalchemy
import numpy as np

# %%
sts = boto3.client('sts')
sts.get_caller_identity()
# Out:
# {'UserId': 'AIDAZZ33YB65BIIUV6X2R',
#  'Account': '674032521146',
#  'Arn': 'arn:aws:iam::674032521146:user/mindex-data-analytics-code-challenge-user',
#  'ResponseMetadata': {'RequestId': '9a79bdac-29c8-45ed-962c-8011cbfc7931',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '9a79bdac-29c8-45ed-962c-8011cbfc7931',
#    'content-type': 'text/xml',
#    'content-length': '438',
#    'date': 'Wed, 24 May 2023 00:09:43 GMT'},
#   'RetryAttempts': 0}}

# %%
s3 = boto3.resource('s3')

bucket = s3.Bucket('mindex-data-analytics-code-challenge')

for obj in bucket.objects.all():
    print(obj.key, obj.last_modified)
# Out:
# bengals.csv 2022-09-08 14:23:10+00:00
# boyd_receiving.csv 2022-09-08 14:23:11+00:00
# chase_receiving.csv 2022-09-08 14:23:11+00:00
# higgins_receiving.csv 2022-09-08 14:23:12+00:00

# %%
bengals_df = pd.read_csv('s3://mindex-data-analytics-code-challenge/bengals.csv')
boyd_df = pd.read_csv('s3://mindex-data-analytics-code-challenge/boyd_receiving.csv')
chase_df = pd.read_csv('s3://mindex-data-analytics-code-challenge/chase_receiving.csv')
higgins_df = pd.read_csv('s3://mindex-data-analytics-code-challenge/higgins_receiving.csv')

# %%
bengals_df['Result'][12]
# Out:
# nan

# %%
bengals_df['Result'] = bengals_df['Result'].apply(lambda x: 'Win' if x == 1.0 else 'Loss')bengals_df

# %%
chase_df= chase_df.rename(columns={'Yards': 'Chase Yards', 'TD': 'Chase TD'})
boyd_df= boyd_df.rename(columns={'Yards': 'Boyd Yards', 'TD': 'Boyd TD'})
higgins_df= higgins_df.rename(columns={'Yards': 'Higgins Yards', 'TD': 'Higgins TD'})

# %%
merged_df = pd.merge(bengals_df, chase_df, on='Week', how='left') 
m2 = pd.merge(merged_df,boyd_df, on='Week', how='left') 
m3 = pd.merge(m2, higgins_df, on='Week', how='left') 

m3
# Out:
#      Week Opponent Location Result  Chase Yards  Chase TD  Boyd Yards
# 0    PRE1       TB     Away    Win          NaN       NaN         NaN  \
# 1    PRE2      WSH     Away   Loss          NaN       NaN         NaN
# 2    PRE3      MIA     Home   Loss          NaN       NaN         NaN
# 3    REG1      MIN     Home    Win        101.0       1.0        32.0
# 4    REG2      CHI     Away   Loss         54.0       1.0        73.0
# 5    REG3      PIT     Away    Win         65.0       2.0        36.0
# 6    REG4      JAX     Home    Win         77.0       0.0       118.0
# 7    REG5       GB     Home   Loss        159.0       1.0        24.0
# 8    REG6      DET     Away    Win         97.0       0.0         7.0
# 9    REG7      BAL     Away    Win        201.0       1.0        39.0
# 10   REG8      NYJ     Away   Loss         32.0       1.0        69.0
# 11   REG9      CLE     Home   Loss         49.0       0.0        11.0
# ...

# %%
conn = psycopg2.connect(
    host="ls-2619b6b15c9bdc80a23f6afb7eee54cf0247da21.ca3yee6xneaj.us-east-1.rds.amazonaws.com",
    database="postgres",
    user="dean_chirieleison",
    password="ceandhirieleison",
port='5432')

# %%
conn
# Out:
# <connection object at 0x176252d60; dsn: 'user=dean_chirieleison password=xxx dbname=postgres host=ls-2619b6b15c9bdc80a23f6afb7eee54cf0247da21.ca3yee6xneaj.us-east-1.rds.amazonaws.com port=5432', closed: 0>

# %%
m3.to_sql('dean_chirieleison', con=conn, if_exists='replace', index=False)
# Out:
# /var/folders/kn/r967brxs57b3lnmh1j2nr3d00000gn/T/ipykernel_1226/2017638620.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   m3.to_sql('dean_chirieleison', con=conn, if_exists='replace', index=False)
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/sql.py:2200, in SQLiteDatabase.execute(self, sql, params)
#    2199 try:
# -> 2200     cur.execute(sql, *args)
#    2201     return cur
#
# UndefinedTable: relation "sqlite_master" does not exist
# LINE 1: SELECT name FROM sqlite_master WHERE type='table' AND name=?...
#                          ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
url = 'postgresql+psycopg2://dean_chirieleison:ceandhirieleison@ls-2619b6b15c9bdc80a23f6afb7eee54cf0247da21.ca3yee6xneaj.us-east-1.rds.amazonaws.com:5432/postgres'
engine = sqlalchemy.create_engine(url)

# %%
m3.to_sql('dean_chirieleison', con=engine, if_exists='replace', index=False)
# Out:
# 25

# %%
bengals_df
# Out:
#      Week Opponent Location Result
# 0    PRE1       TB     Away    Win
# 1    PRE2      WSH     Away   Loss
# 2    PRE3      MIA     Home   Loss
# 3    REG1      MIN     Home    Win
# 4    REG2      CHI     Away   Loss
# 5    REG3      PIT     Away    Win
# 6    REG4      JAX     Home    Win
# 7    REG5       GB     Home   Loss
# 8    REG6      DET     Away    Win
# 9    REG7      BAL     Away    Win
# 10   REG8      NYJ     Away   Loss
# 11   REG9      CLE     Home   Loss
# 12  REG10      NaN      NaN   Loss
# 13  REG11       LV     Away    Win
# 14  REG12      PIT     Home    Win
# 15  REG13      LAC     Home   Loss
# 16  REG14       SF     Home   Loss
# 17  REG15      DEN     Away    Win
# 18  REG16      BAL     Home    Win
# 19  REG17       KC     Home    Win
# 20  REG18      CLE     Away   Loss
# 21  POST1       LV     Home    Win
# 22  POST2      TEN     Away    Win
# 23  POST3       KC     Away    Win
# 24  POST4      LAR  Neutral   Loss
